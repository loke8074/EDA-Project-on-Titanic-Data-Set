# %%
#--------------------------------THIS IS A EXPLORATORY DATA ANALYSIS (EDA) PROJECT--------------------------------
""" Project Description: This python EDA project is for analysing the Titanic Train Data set Which analyse how many people were
survived and their names,as well as their details like names,age,sex,cabin,relations,etc.."""
# Out:
# ' Project Description: This python EDA project is for analysing the Titanic Train Data set Which analyse how many people were\nsurvived and their names,as well as their details like names,age,sex,cabin,relations,etc..'

# %%
# importing pyforest which imports all libraries at once
import pyforest

# %%
# Reading data (or) data gathering
data=pd.read_csv('Titanic-Train-Data.csv')
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# Data comes as a raw data
# Now we should clean the data which is also called data cleaning

# %%
# "shape" function is used to know how the data arranged i.e.,(rows*columns)
data.shape
# it is used to check how many rows and columns are present in a data
# Out:
# (891, 12)

# %%
# Firstly we need to know the information about the data.
# info() is used to know the information about the data.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  891 non-null    int64
#  1   Survived     891 non-null    int64
#  2   Pclass       891 non-null    int64
#  3   Name         891 non-null    object
#  4   Sex          891 non-null    object
#  5   Age          714 non-null    float64
#  6   SibSp        891 non-null    int64
#  7   Parch        891 non-null    int64
#  8   Ticket       891 non-null    object
#  9   Fare         891 non-null    float64
#  10  Cabin        204 non-null    object
#  11  Embarked     889 non-null    object
# dtypes: float64(2), int64(5), object(5)
# memory usage: 83.7+ KB

# %%
# If you want to describe about the data then use describe()
data.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
# If you want to know only first five and last five column's data then use head() and tail()
data.head() # This gives only first five column's value
data.tail() # This gives only last five column's value
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
# For knowing only about the single column's data in a dataset use 'dtypes'
# dtypes is used to know only column's type of data seperately
data.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
# If we want to access particular column's values in a data then use column's name inside the data like this
# data['column_name']
data['Name']
# Out:
# 0                                Braund, Mr. Owen Harris
# 1      Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                                 Heikkinen, Miss. Laina
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                               Allen, Mr. William Henry
#                              ...
# 886                                Montvila, Rev. Juozas
# 887                         Graham, Miss. Margaret Edith
# 888             Johnston, Miss. Catherine Helen "Carrie"
# 889                                Behr, Mr. Karl Howell
# 890                                  Dooley, Mr. Patrick
# Name: Name, Length: 891, dtype: object

# %%
# In this titanic's data there are lots of null values,unwanted objects,unwanted columns,empty values,etc.
# So we should clean the data based on our requirement

# %%
# Changing Age's column values Male and Female to 0's & 1's
# from sklearn library import preprocessing 
# "laeblencoding" is used to convert objects into o's & 1's of a categorical daata
'''Example for categorical data.(cats,dogs) are comes under anaimal class.so categorical data is not measurable.Only knowing of
how many are there'''
# scikit-learn is used to perform statistical operations like regression,clustering,etc.
from sklearn import preprocessing

label_encoder=preprocessing.LabelEncoder()

data['Sex']=label_encoder.fit_transform(data['Sex'])

data['Sex'].value_counts() # converts male and female to 0's & 1's
# Out:
# 1    577
# 0    314
# Name: Sex, dtype: int64

# %%
# If we want to check how many null values are present in a data then use "isnull().sum()"
data.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
# In the titanic data there are some unwanted columns,so if we want to remove those columns then use drop()
# drop() is used to delete unwanted columns or rows or data
data=data.drop(['Ticket','Cabin','Name'],axis=1)
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0   NaN      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# In this data some null values are there.so we fill the nullvalues with a number or name or symbol based on our requirement
data['Age']=data['Age'].fillna(value=28)
data

# %%
# In this data 'embarked' contains two null values as well as it seems just like a categorical data Ex: 'Sex' column
# So first we have to check how many repeated values are present in 'Embarked' column'
data['Embarked'].value_counts()
# Out:
# S    644
# C    168
# Q     77
# Name: Embarked, dtype: int64

# %%
data.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       2
# dtype: int64

# %%
# In this data the 'embarked' column contains 'S','C','Q' categorical data so that again we want to convert into 0's & 1's
# Of all these the 'S' repeated so many times.So we can convert into 0's & 1's
# But first we have to add under a variable using a groupby() function
g=data.groupby('Survived')
g['Embarked'].value_counts()
# Out:
# Survived  Embarked
# 0         S           427
#           C            75
#           Q            47
# 1         S           217
#           C            93
#           Q            30
# Name: Embarked, dtype: int64

# %%
data['Embarked']=data['Embarked'].fillna(value='S')
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# lets check whether it was filled with 'S' or not.
# In the 830 row the embarked column's value filled with 'S'
data.head(830)
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 825          826         0       3    1  28.0      0      0   6.9500        Q
# 826          827         0       3    1  28.0      0      0  56.4958        S
# 827          828         1       2    1   1.0      0      2  37.0042        C
# 828          829         1       3    1  28.0      0      0   7.7500        Q
# 829          830         1       1    0  62.0      0      0  80.0000        S
#
# [830 rows x 9 columns]

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked
# 0              1         0       3    1  22.0      1      0   7.2500        S
# 1              2         1       1    0  38.0      1      0  71.2833        C
# 2              3         1       3    0  26.0      0      0   7.9250        S
# 3              4         1       1    0  35.0      1      0  53.1000        S
# 4              5         0       3    1  35.0      0      0   8.0500        S
# ..           ...       ...     ...  ...   ...    ...    ...      ...      ...
# 886          887         0       2    1  27.0      0      0  13.0000        S
# 887          888         1       1    0  19.0      0      0  30.0000        S
# 888          889         0       3    0  28.0      1      2  23.4500        S
# 889          890         1       1    1  26.0      0      0  30.0000        C
# 890          891         0       3    1  32.0      0      0   7.7500        Q
#
# [891 rows x 9 columns]

# %%
# Lets see how many survived 
from sklearn import preprocessing
label_encoder=preprocessing.LabelEncoder()
data['Embarked']=label_encoder.fit_transform(data['Embarked'])
data['Embarked'].value_counts()
# Out:
# 2    646
# 0    168
# 1     77
# Name: Embarked, dtype: int64

# %%
# Data Visualisation of how many survived
sns.countplot(x=data['Embarked'],hue=data['Survived'])
plt.show()

# %%
# Lets see how thevdata was correlated
# Using correlation we can visualise the good bad perfect correlation between the columns values
# corr() is used to check the correlation
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000 -0.005007 -0.035144  0.042939  0.034212 -0.057527
# Survived       -0.005007  1.000000 -0.338481 -0.543351 -0.064910 -0.035322
# Pclass         -0.035144 -0.338481  1.000000  0.131900 -0.339898  0.083081
# Sex             0.042939 -0.543351  0.131900  1.000000  0.081163 -0.114631
# Age             0.034212 -0.064910 -0.339898  0.081163  1.000000 -0.233296
# SibSp          -0.057527 -0.035322  0.083081 -0.114631 -0.233296  1.000000
# Parch          -0.001652  0.081629  0.018443 -0.245489 -0.172482  0.414838
# Fare            0.012658  0.257307 -0.549500 -0.182333  0.096688  0.159651
# Embarked        0.013128 -0.167675  0.162098  0.108262 -0.018754  0.068230
#
#                 Parch      Fare  Embarked
# PassengerId -0.001652  0.012658  0.013128
# Survived     0.081629  0.257307 -0.167675
# Pclass       0.018443 -0.549500  0.162098
# Sex         -0.245489 -0.182333  0.108262
# ...

# %%
# lets see graphical representationn of the correlation
data.plot(x='Survived',y=['SibSp','Parch'],kind='bar')
plt.show()

# %%
# seaborn is a library which is used to represent plot graphs based on matplotlib
# heatmap is used to check the correlation in a colouring shades representation
sns.heatmap(data.corr())
# Out:
# <AxesSubplot: >

# %%
data['Family']=data['SibSp']+data['Parch']+1
data=data.drop(['SibSp','Parch'],axis=1)
data=data.drop('PassengerId',axis=1)
data=data.drop('Embarked',axis=1)
data
# Out:
#      Survived  Pclass  Sex   Age     Fare  Family
# 0           0       3    1  22.0   7.2500       2
# 1           1       1    0  38.0  71.2833       2
# 2           1       3    0  26.0   7.9250       1
# 3           1       1    0  35.0  53.1000       2
# 4           0       3    1  35.0   8.0500       1
# ..        ...     ...  ...   ...      ...     ...
# 886         0       2    1  27.0  13.0000       1
# 887         1       1    0  19.0  30.0000       1
# 888         0       3    0  28.0  23.4500       4
# 889         1       1    1  26.0  30.0000       1
# 890         0       3    1  32.0   7.7500       1
#
# [891 rows x 6 columns]

# %%
data
# Out:
#      Survived  Pclass  Sex   Age     Fare  Family
# 0           0       3    1  22.0   7.2500       2
# 1           1       1    0  38.0  71.2833       2
# 2           1       3    0  26.0   7.9250       1
# 3           1       1    0  35.0  53.1000       2
# 4           0       3    1  35.0   8.0500       1
# ..        ...     ...  ...   ...      ...     ...
# 886         0       2    1  27.0  13.0000       1
# 887         1       1    0  19.0  30.0000       1
# 888         0       3    0  28.0  23.4500       4
# 889         1       1    1  26.0  30.0000       1
# 890         0       3    1  32.0   7.7500       1
#
# [891 rows x 6 columns]

# %%
x=data.drop('Survived',axis=1).values
y=data['Survived'].values

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=100)

# %%
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train) #sending data to train by 70%
lrpred=lr.predict(x_test)

# %%
accuracy_score(y_test,lrpred)
# Out:
# 0.7910447761194029

# %%
from sklearn.model_selection import GridSearchCV
#creating hyperparameter grid
c_space=np.logspace(-5,8,15)
param_grid={'C':c_space}
# Instantiating the gridsearchcv object
logreg_cv=GridSearchCV(lr,param_grid,cv=5)
logreg_cv.fit(x_train,y_train)
# print the tuned parameters and score
print('Tuned Logistic Regression Parameters: {}'.format(logreg_cv.best_params_))
print('Best Score is {}'.format(logreg_cv.best_score_))
# Out:
# Tuned Logistic Regression Parameters: {'C': 31.622776601683793}
# Best Score is 0.8042193548387097
